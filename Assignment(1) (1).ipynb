# %% [markdown]
# #### Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input("Enter a number:"))
if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num,"is not a prime number")
            break
    else:
        print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# Enter a number: 5
# 5 is a prime number

# %% [markdown]
# #### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# %%
import random
A = random.randint(1,10)
B = random.randint(1,10)
print("Give any Two numbers:")
print( A , "X" , B)
random_input= int(input("Enter Your Answer:"))
print(user_input)
output = A * B
if user_input == output:
    print("Correct Answer")
else:
    print("The Given Answer IS wrong")
# Out:
# Give any Two numbers:
# 1 X 10
# Enter Your Answer: 10
# 10
# Correct Answer

# %% [markdown]
# #### Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
for i in range(100,201):
    if i % 2 ==0:
        print("Square of",i , "is", i*i)
# Out:
# Square of 100 is 10000
# Square of 102 is 10404
# Square of 104 is 10816
# Square of 106 is 11236
# Square of 108 is 11664
# Square of 110 is 12100
# Square of 112 is 12544
# Square of 114 is 12996
# Square of 116 is 13456
# Square of 118 is 13924
# Square of 120 is 14400
# Square of 122 is 14884
# Square of 124 is 15376
# Square of 126 is 15876
# Square of 128 is 16384
# Square of 130 is 16900
# Square of 132 is 17424
# Square of 134 is 17956
# Square of 136 is 18496
# Square of 138 is 19044
# Square of 140 is 19600
# Square of 142 is 20164
# Square of 144 is 20736
# Square of 146 is 21316
# Square of 148 is 21904
# Square of 150 is 22500
# Square of 152 is 23104
# Square of 154 is 23716
# Square of 156 is 24336
# Square of 158 is 24964
# Square of 160 is 25600
# Square of 162 is 26244
# Square of 164 is 26896
# Square of 166 is 27556
# Square of 168 is 28224
# Square of 170 is 28900
# Square of 172 is 29584
# Square of 174 is 30276
# Square of 176 is 30976
# Square of 178 is 31684
# ...

# %% [markdown]
# #### A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
### Given Details
Room_charges = 2000 
Doctor_Consultation_Fee = 1500
Lab_Test_Charges = 300
Discount = 0.10

#Patient Details
Patient_Stayed = 4
Lab_Test = 3
Medicine_Bill = 2400

# %%
Total_Room_Bill = Room_charges*Patient_Stayed
Total_Lab_Test= Lab_Test_Charges*Lab_Test
Final_Bill = Total_Room_Bill + Total_Lab_Test
if Final_Bill > 10000:
    dicount = Total_Bill * 0.1
else:
    Discount = 0

Bill_after = Final_Bill - Discount
print("-- Hospital Bill--")
print("Room_Charges:",Room_charges)
print("Lab_Test_Charges:",Lab_Test_Charges)
print("Doctor_Consultation:",Doctor_Consultation_Fee)
print("Total_Room_Bill:",Total_Room_Bill)
print("Total_Lab_Bill:",Total_Lab_Test)
print("Finall_Bill:",Bill_after)
# Out:
# -- Hospital Bill--
# Room_Charges: 2000
# Lab_Test_Charges: 300
# Doctor_Consultation: 1500
# Total_Room_Bill: 8000
# Total_Lab_Bill: 900
# Finall_Bill: 8900
